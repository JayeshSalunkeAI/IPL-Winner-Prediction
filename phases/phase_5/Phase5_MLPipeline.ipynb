# %% [markdown]
# # Phase 5 Pipeline
#
# Train LightGBM, CatBoost, and stacking (XGBoost + Random Forest + Logistic Regression) with overfit-aware tuning.

# %%
from pathlib import Path
import json
import pandas as pd
from IPython.display import Image, display

# %% [markdown]
# ## Train models

# %%
# Mode A (max accuracy): selection-metric accuracy\n
# !python "phase5_train_pipeline.py" --input "../phase_4/results/phase4_dataset.csv" --results-dir "results" --artifacts-dir "artifacts" --drop-no-result --min-category-freq 12 --max-player-categories 70 --cv-folds 5 --search-mode fast --selection-metric accuracy\n
\n
# Mode B (lower overfit): add --max-fit-gap 0.12\n
# !python "phase5_train_pipeline.py" --input "../phase_4/results/phase4_dataset.csv" --results-dir "results" --artifacts-dir "artifacts" --drop-no-result --min-category-freq 10 --max-player-categories 90 --cv-folds 4 --search-mode fast --selection-metric accuracy --max-fit-gap 0.12
# Out:
# Phase 5 training:   0%|                      | 0/5 [00:00<?, ?model/s, lgbm_gen]/home/vectone/MyProjects/IPL-Winner-Prediction/.venv/lib/python3.10/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /home/vectone/MyProjects/IPL-Winner-Prediction/.venv/lib/python3.10/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# ...

# %% [markdown]
# ## Review outputs

# %%
results_dir = Path("results")
artifacts_dir = Path("artifacts")

metrics = pd.read_csv(results_dir / "phase5_model_comparison_metrics.csv")
meta = json.loads((artifacts_dir / "phase5_model_metadata.json").read_text(encoding="utf-8"))

display(metrics)
print("Best model:", meta.get("best_model"))
print("Best model params:", meta.get("best_model_params"))
meta.get("best_model_test_metrics", {})

# %% [markdown]
# ## Review charts

# %%
display(Image(filename=str(results_dir / "phase5_model_comparison_accuracy.png")))
display(Image(filename=str(results_dir / "phase5_model_comparison_f1.png")))
display(Image(filename=str(results_dir / "phase5_overfit_gap.png")))
display(Image(filename=str(results_dir / "phase5_best_model_confusion_matrix.png")))
display(Image(filename=str(results_dir / "phase5_best_model_reliability_plot.png")))
